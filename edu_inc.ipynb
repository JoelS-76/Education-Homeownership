# %%
import pandas as pd
import numpy as np

# %%
# read in csv
edu_inc_df = pd.read_csv('education_co_income.csv')

# %%
edu_inc_df.head()
# Out:
#           Area name  \
# 0      Adams County
# 1    Alamosa County
# 2   Arapahoe County
# 3  Archuleta County
# 4       Baca County
#
#    Percent of adults with less than a high school diploma, 1970  \
# 0                                               37.3
# 1                                               40.2
# 2                                               23.9
# 3                                               54.2
# 4                                               53.7
#
#    Percent of adults with a high school diploma only, 1970  \
# 0                                               41.3
# 1                                               29.7
# 2                                               36.3
# 3                                               31.8
# 4                                               30.4
#
#    Percent of adults completing some college (1-3 years), 1970  \
# 0                                               12.8
# ...

# %%
edu_inc_df.set_index('Area name')
# Out:
#                    Percent of adults with less than a high school diploma, 1970  \
# Area name
# Adams County                                                    37.3
# Alamosa County                                                  40.2
# Arapahoe County                                                 23.9
# Archuleta County                                                54.2
# Baca County                                                     53.7
# ...                                                              ...
# Summit County                                                   32.0
# Teller County                                                   32.3
# Washington County                                               49.2
# Weld County                                                     42.9
# Yuma County                                                     49.9
#
#                    Percent of adults with a high school diploma only, 1970  \
# Area name
# ...

# %%
L = ['less']
no_hs_df = edu_inc_df.loc[:, edu_inc_df.columns.str.contains('|'.join(L))]

# %%
O = ['only']
hs_df = edu_inc_df.loc[:, edu_inc_df.columns.str.contains('|'.join(O))]

# %%
S = ['some']
some_coll_df = edu_inc_df.loc[:, edu_inc_df.columns.str.contains('|'.join(S))]

# %%
F = ['four']
coll_grad_df = edu_inc_df.loc[:, edu_inc_df.columns.str.contains('|'.join(F))]

# %%
no_hs_df.head()
# Out:
#    Percent of adults with less than a high school diploma, 1970  \
# 0                                               37.3
# 1                                               40.2
# 2                                               23.9
# 3                                               54.2
# 4                                               53.7
#
#    Percent of adults with less than a high school diploma, 1980  \
# 0                                               26.5
# 1                                               29.1
# 2                                               11.4
# 3                                               27.7
# 4                                               37.8
#
#    Percent of adults with less than a high school diploma, 1990  \
# 0                                               21.2
# 1                                               23.1
# 2                                                8.5
# 3                                               19.1
# ...

# %%
no_hs_df.set_index(edu_inc_df['Area name'])
# Out:
#                    Percent of adults with less than a high school diploma, 1970  \
# Area name
# Adams County                                                    37.3
# Alamosa County                                                  40.2
# Arapahoe County                                                 23.9
# Archuleta County                                                54.2
# Baca County                                                     53.7
# ...                                                              ...
# Summit County                                                   32.0
# Teller County                                                   32.3
# Washington County                                               49.2
# Weld County                                                     42.9
# Yuma County                                                     49.9
#
#                    Percent of adults with less than a high school diploma, 1980  \
# Area name
# ...

# %%
hs_df.set_index(edu_inc_df['Area name'])
# Out:
#                    Percent of adults with a high school diploma only, 1970  \
# Area name
# Adams County                                                    41.3
# Alamosa County                                                  29.7
# Arapahoe County                                                 36.3
# Archuleta County                                                31.8
# Baca County                                                     30.4
# ...                                                              ...
# Summit County                                                   31.4
# Teller County                                                   44.5
# Washington County                                               33.4
# Weld County                                                     32.4
# Yuma County                                                     32.1
#
#                    Percent of adults with a high school diploma only, 1980  \
# Area name
# ...

# %%
some_coll_df.set_index(edu_inc_df['Area name'])
# Out:
#                    Percent of adults completing some college (1-3 years), 1970  \
# Area name
# Adams County                                                    12.8
# Alamosa County                                                  12.3
# Arapahoe County                                                 18.3
# Archuleta County                                                 8.1
# Baca County                                                      8.8
# ...                                                              ...
# Summit County                                                   18.4
# Teller County                                                   10.4
# Washington County                                                9.1
# Weld County                                                     12.8
# Yuma County                                                      9.7
#
#                    Percent of adults completing some college (1-3 years), 1980  \
# Area name
# ...

# %%
coll_grad_df.set_index(edu_inc_df['Area name'])
# Out:
#                    Percent of adults completing four years of college or higher, 1970  \
# Area name
# Adams County                                                     8.6
# Alamosa County                                                  17.8
# Arapahoe County                                                 21.5
# Archuleta County                                                 5.9
# Baca County                                                      7.1
# ...                                                              ...
# Summit County                                                   18.2
# Teller County                                                   12.8
# Washington County                                                8.3
# Weld County                                                     12.0
# Yuma County                                                      8.3
#
#                    Percent of adults completing four years of college or higher, 1980
# Area name
# ...
